# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('laptopPrice.csv')
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.shape
# Out:
# (823, 19)

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.isna().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
cat =list(df.columns[df.dtypes == 'object'])
con = list(df.columns[df.dtypes !='object'])

# %%
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
df[con].describe().T
# Out:
#                    count          mean           std      min      25%  \
# Price              823.0  76745.177400  45101.790525  16990.0  46095.0
# Number of Ratings  823.0    315.301337   1047.382654      0.0      0.0
# Number of Reviews  823.0     37.609964    121.728017      0.0      0.0
#
#                        50%      75%       max
# Price              64990.0  89636.0  441990.0
# Number of Ratings     17.0    139.5   15279.0
# Number of Reviews      2.0     18.0    1947.0

# %%
df[cat].describe().T
# Out:
#                 count unique      top freq
# brand             823      8     ASUS  249
# processor_brand   823      3    Intel  610
# processor_name    823     11  Core i5  290
# processor_gnrtn   823      8     11th  334
# ram_gb            823      4     8 GB  418
# ram_type          823      6     DDR4  709
# ssd               823      7   512 GB  398
# hdd               823      4     0 GB  621
# os                823      3  Windows  779
# os_bit            823      2   64-bit  714
# graphic_card_gb   823      5     0 GB  577
# weight            823      3   Casual  520
# warranty          823      4   1 year  509
# Touchscreen       823      2       No  726
# msoffice          823      2       No  542
# rating            823      5  4 stars  444

# %% [markdown]
# # univariate analysis

# %% [markdown]
# ## 1.categorial analysis

# %%
df['brand'].value_counts()
# Out:
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: brand, dtype: int64

# %%
df['brand'].value_counts().plot(kind='bar',
                              title='count by brand',
                              xlabel='brand',
                              ylabel='count',
                              color='violet')
# Out:
# <Axes: title={'center': 'count by brand'}, xlabel='brand', ylabel='count'>

# %%
df['processor_brand'].value_counts().plot(kind='bar',
                              title='count by processor_brand',
                              xlabel='processor_brand',
                              ylabel='count',
                              color='violet')
# Out:
# <Axes: title={'center': 'count by processor_brand'}, xlabel='processor_brand', ylabel='count'>

# %%
df['processor_name'].value_counts().plot(kind='bar',
                              title='count by processor_name',
                              xlabel='processor_name',
                              ylabel='count',
                              color='violet')
# Out:
# <Axes: title={'center': 'count by processor_name'}, xlabel='processor_name', ylabel='count'>

# %% [markdown]
# ## 2.continuous analysis

# %%
for i in con:
    sns.histplot(data=df,x=i,kde=True,color= 'green')
    plt.title(f'Histogram for {i}')
    plt.show()

# %%
x=1
plt.figure(figsize=(12,12))
for i in con:
    plt.subplot(2,2,x)
    x=x+1
    sns.histplot(data=df,x=i,kde=True)
    plt.title(f'Histogram for {i}')
plt.show()

# %% [markdown]
# # bivariate analysis

# %% [markdown]
# #### 1. con vs con analysis

# %%
plt.scatter(df['Price'],df['Number of Ratings'],color='purple')
plt.title('price vs num of ratings')
plt.xlabel('Price')
plt.ylabel('Number of Ratings')
plt.show()

# %%
plt.scatter(df['Price'],df['Number of Reviews'],color='purple')
plt.title('price vs num of Reviews')
plt.xlabel('Price')
plt.ylabel('Number of Reviews')
plt.show()

# %%
plt.scatter(df['Number of Ratings'],df['Number of Reviews'],color='purple')
plt.title('ratings vs Reviews')
plt.xlabel('Number of Ratings')
plt.ylabel('Number of Reviews')
plt.show()

# %%
df.corr()
# Out:
#                       Price  Number of Ratings  Number of Reviews
# Price              1.000000          -0.140392          -0.148738
# Number of Ratings -0.140392           1.000000           0.989626
# Number of Reviews -0.148738           0.989626           1.000000

# %%
sns.heatmap(df.corr(),annot=True,fmt='6f')
# Out:
# <Axes: >

# %% [markdown]
# ### 2.cat vs con analysis

# %%
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(2,2,x)
    x=x+1
    sns.boxplot(data=df,x='brand',y=i)
    plt.title(f'Boxplot Of {i} vs Brands')
plt.show()

# %%
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(2,2,x)
    x=x+1
    sns.boxplot(data=df,x='processor_brand',y=i)
    plt.title(f'Boxplot Of {i} vs processor_Brands')
plt.show()

# %%
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(2,2,x)
    x=x+1
    sns.boxplot(data=df,x='processor_name',y=i)
    plt.title(f'Boxplot Of {i} vs processor_name')
plt.show()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='brand')

# %%
ctab=pd.crosstab(df['brand'],df['ram_gb'])
ctab
# Out:
# ram_gb  16 GB  32 GB  4 GB  8 GB
# brand
# APPLE      13      1     1    13
# ASUS       59      0    89   101
# Avita       1      0     1    12
# DELL       16      0    39    96
# HP         35      0    38    63
# Lenovo     26      0    40    78
# MSI        18      0     5    27
# acer        9      1    13    28

# %%
ctab2=pd.crosstab(df['brand'],df['ssd'])
ctab2
# Out:
# ssd     0 GB  1024 GB  128 GB  2048 GB  256 GB  3072 GB  512 GB
# brand
# APPLE      0        8       0        0       7        0      13
# ASUS      39       59       1        1      49        1      99
# Avita      1        1       0        0       6        0       6
# DELL      25        4       0        0      57        0      65
# HP        20       14       2        0      17        0      83
# Lenovo    16       12       0        0      31        0      85
# MSI        8        9       0        0       4        0      29
# acer      15        4       0        1      13        0      18

# %%
ctab1=pd.crosstab(df['processor_brand'],df['os'])
ctab1
# Out:
# os               DOS  Mac  Windows
# processor_brand
# AMD                1    0      188
# Intel             15    4      591
# M1                 0   24        0

# %%
sns.heatmap(ctab1,annot=True,fmt='d')
# Out:
# <Axes: xlabel='os', ylabel='processor_brand'>

# %%
sns.heatmap(ctab2,annot=True,fmt='d')
# Out:
# <Axes: xlabel='ssd', ylabel='brand'>

# %%
sns.heatmap(ctab,annot=True,fmt='d')
# Out:
# <Axes: xlabel='ram_gb', ylabel='brand'>

# %%
c = pd.crosstab(df['brand'],df['os_bit'])
c
# Out:
# os_bit  32-bit  64-bit
# brand
# APPLE        0      28
# ASUS        40     209
# Avita        0      14
# DELL        13     138
# HP          14     122
# Lenovo      25     119
# MSI          8      42
# acer         9      42

# %%
sns.heatmap(c,annot=True,fmt='d')
# Out:
# <Axes: xlabel='os_bit', ylabel='brand'>

# %%
sns.pairplot(df,hue='os_bit')

# %%
plt.figure(figsize=(20,20))
x=1
for i in con:
    plt.subplot(2,2,x)
    x=x+1
    sns.boxplot(data=df, x='os_bit',y=i)
    plt.title(f'boxplot is {i} vs os')
    plt.show()
